# %%
import os
import chromadb
from datasets import load_dataset
from google import genai
import pandas as pd
import sys
import requests
from datasets import Dataset

# %% [markdown]
# ### Context Ingestion

# %%
# Local environment configuration
CHROMA_PATH = r"chroma_db"

# Block Execution (Remove to download and index SQuAD data into ChromaDB)
raise ValueError("Script already executed ")

# Connect to local ChromaDB instance
chroma_client = chromadb.PersistentClient(path=CHROMA_PATH)
collection = chroma_client.get_or_create_collection(name="squad_benchmark")

# Download and load the SQuAD dataset automatically from Hugging Face
print("Downloading SQuAD dataset from Hugging Face...")
raw_dataset = load_dataset("rajpurkar/squad", split="train")

# Connection to the Gemini API Client using Google Cloud Vertex AI
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "gcp-key.json"

ai_client = genai.Client(
    vertexai=True,
    project="info-h512-project-rag-project",
    location="europe-west1"
)

documents = []
metadata = []
ids = []
embeddings = []

# Selection of 500 unique SQuAD context passages for embedding and indexing
max_passages = 500
seen_contexts = set()

print(f"Processing and embedding the first {max_passages} unique SQuAD contexts...")

for i, entry in enumerate(raw_dataset):
    context_text = entry["context"]
    
    # Select unique context passages to avoid redundancy in the vector database
    if context_text in seen_contexts:
        continue
    seen_contexts.add(context_text)
    
    # Store text and unique ID mapping
    documents.append(context_text)
    doc_id = f"SQUAD_{len(seen_contexts)}"
    ids.append(doc_id)
    
    # Extract metadata provided natively by the dataset
    meta = {
        "title": entry["title"],
        "id": entry["id"]
    }
    metadata.append(meta)
    
    # Calculate vector embeddings using Vertex AI text embedding model
    response = ai_client.models.embed_content(
        model="text-embedding-004",
        contents=context_text
    )
    embeddings.append(response.embeddings[0].values)
    
    # Break early once we hit our sample target scale
    if len(seen_contexts) >= max_passages:
        break

# Save the SQuAD text strings and vector coordinates into your local storage
print("Saving SQuAD records to local ChromaDB storage...")
collection.upsert(
    documents=documents,
    embeddings=embeddings,
    metadatas=metadata,
    ids=ids
)
print(f"Successfully indexed {len(documents)} SQuAD passages!")

# %% [markdown]
# ### Evaluation Dataset Generation

# %%
# Connect to local database
CHROMA_PATH = r"chroma_db"
chroma_client = chromadb.PersistentClient(path=CHROMA_PATH)
collection = chroma_client.get_or_create_collection(name="squad_benchmark")

# Retrieve all documents physically stored in database
all_db_data = collection.get(include=['documents'])
indexed_contexts = set(all_db_data['documents'])

print(f"Number of documents indexed locally: {len(indexed_contexts)}")

# Load original SQuAD dataset to match questions
print("Searching for associated questions in SQuAD...")
raw_dataset = load_dataset("rajpurkar/squad", split="train")

# Iterate through SQuAD and extract questions for indexed documents
eval_pairs = []
for entry in raw_dataset:
    if entry["context"] in indexed_contexts:
        eval_pairs.append({
            "question": entry["question"],
            "expected_answer": entry["answers"]["text"][0] if entry["answers"]["text"] else "N/A",
            "context": entry["context"]
        })
    
    # Stop once we have a good sample of questions for testing
    if len(eval_pairs) >= 500:
        break

# Store to csv file
df = pd.DataFrame(eval_pairs)
df.to_csv("squad_eval_pairs.csv", index=False)

# Display the questions for testing
print("\n Questions - Answers \n")
for idx, pair in enumerate(eval_pairs, 1):
    print(f"\nQuestion {idx}: {pair['question']}")
    print(f"Expected answer {idx}: {pair['expected_answer']}")
# Out:
# Number of documents indexed locally: 500
# Searching for associated questions in SQuAD...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#  Questions - Answers
#
#
# Question 1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# Expected answer 1: Saint Bernadette Soubirous
#
# Question 2: What is in front of the Notre Dame Main Building?
# Expected answer 2: a copper statue of Christ
#
# Question 3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# Expected answer 3: the Main Building
#
# Question 4: What is the Grotto at Notre Dame?
# Expected answer 4: a Marian place of prayer and reflection
#
# Question 5: What sits on top of the Main Building at Notre Dame?
# Expected answer 5: a golden statue of the Virgin Mary
#
# Question 6: When did the Scholastic Magazine of Notre dame begin publishing?
# Expected answer 6: September 1876
#
# Question 7: How often is Notre Dame's the Juggler published?
# Expected answer 7: twice
#
# Question 8: What is the daily student paper at Notre Dame called?
# Expected answer 8: The Observer
#
# Question 9: How many student news papers are found at Notre Dame?
# Expected answer 9: three
#
# Question 10: In what year did the student paper Common Sense begin publication at Notre Dame?
# Expected answer 10: 1987
#
# Question 11: Where is the headquarters of the Congregation of the Holy Cross?
# Expected answer 11: Rome
#
# Question 12: What is the primary seminary of the Congregation of the Holy Cross?
# Expected answer 12: Moreau Seminary
#
# Question 13: What is the oldest structure at Notre Dame?
# Expected answer 13: Old College
#
# Question 14: What individuals live at Fatima House at Notre Dame?
# Expected answer 14: Retired priests and brothers
#
# Question 15: Which prize did Frederick Buechner create?
# Expected answer 15: Buechner Prize for Preaching
#
# Question 16: How many BS level degrees are offered in the College of Engineering at Notre Dame?
# Expected answer 16: eight
#
# Question 17: In what year was the College of Engineering at Notre Dame formed?
# Expected answer 17: 1920
#
# Question 18: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
# Expected answer 18: the College of Science
#
# Question 19: How many departments are within the Stinson-Remick Hall of Engineering?
# Expected answer 19: five
#
# Question 20: The College of Science began to offer civil engineering courses beginning at what time at Notre Dame?
# Expected answer 20: the 1870s
#
# Question 21: What entity provides help with the management of time for new students at Notre Dame?
# Expected answer 21: Learning Resource Center
#
# Question 22: How many colleges for undergraduates are at Notre Dame?
# Expected answer 22: five
#
# Question 23: What was created at Notre Dame in 1962 to assist first year students?
# Expected answer 23: The First Year of Studies program
#
# Question 24: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
# Expected answer 24: U.S. News & World Report
#
# Question 25: The granting of Doctorate degrees first occurred in what year at Notre Dame?
# Expected answer 25: 1924
#
# Question 26: What type of degree is an M.Div.?
# Expected answer 26: Master of Divinity
#
# Question 27: Which program at Notre Dame offers a Master of Education degree?
# Expected answer 27: Alliance for Catholic Education
#
# Question 28: In what year was a Master of Arts course first offered at Notre Dame?
# Expected answer 28: 1854
#
# Question 29: Which department at Notre Dame is the only one to not offer a PhD program?
# Expected answer 29: Department of Pre-Professional Studies
#
# Question 30: What institute at Notre Dame studies  the reasons for violent conflict?
# Expected answer 30: Joan B. Kroc Institute for International Peace Studies
#
# Question 31: What is the title of Notre Dame's Theodore Hesburgh?
# Expected answer 31: President Emeritus of the University of Notre Dame
#
# Question 32: In what year was the Joan B. Kroc Institute for International Peace Studies founded?
# Expected answer 32: 1986
#
# Question 33: To whom was John B. Kroc married?
# Expected answer 33: Ray Kroc
#
# Question 34: What company did Ray Kroc own?
# Expected answer 34: McDonald's
#
# Question 35: How many stories tall is the main library at Notre Dame?
# Expected answer 35: 14
#
# Question 36: What is the name of the main library at Notre Dame?
# Expected answer 36: Theodore M. Hesburgh Library
#
# Question 37: In what year was the Theodore M. Hesburgh Library at Notre Dame finished?
# Expected answer 37: 1963
#
# Question 38: Which artist created the mural on the Theodore M. Hesburgh Library?
# Expected answer 38: Millard Sheets
#
# Question 39: What is a common name to reference the mural created by Millard Sheets at Notre Dame?
# Expected answer 39: Touchdown Jesus
#
# Question 40: How many incoming students did Notre Dame admit in fall 2015?
# Expected answer 40: 3,577
#
# Question 41: What percentage of students were admitted to Notre Dame in fall 2015?
# Expected answer 41: 19.7%
#
# Question 42: Where does Notre Dame rank in terms of academic profile among research universities in the US?
# Expected answer 42: the top 10 to 15 in the nation
#
# Question 43: What percentage of students at Notre Dame participated in the Early Action program?
# Expected answer 43: 39.1%
#
# Question 44: How many miles does the average student at Notre Dame travel to study there?
# Expected answer 44: more than 750 miles
#
# Question 45: Where did U.S. News & World Report rank Notre Dame in its 2015-2016 university rankings?
# Expected answer 45: 18th overall
#
# Question 46: Forbes.com placed Notre Dame at what position compared to other US research universities?
# Expected answer 46: 8th
#
# Question 47: The undergrad school at the Mendoza College of Business was ranked where according to BusinessWeek?
# Expected answer 47: 1st overall
#
# Question 48: In 2014 what entity named Notre Dame 10th best of all American universities?
# Expected answer 48: USA Today
#
# Question 49: What percentage of Notre Dame students decide to study abroad?
# Expected answer 49: 57.6%
#
# Question 50: What person was the Director of the Science Museum at Notre Dame in the late 19th century?
# Expected answer 50: Father Joseph Carrier, C.S.C.
#
# Question 51: What was the lifespan of John Augustine Zahm?
# Expected answer 51: 1851–1921
#
# Question 52: What program did John Augustine Zahm come to co-direct at Nore Dame?
# Expected answer 52: the Science Department
#
# Question 53: What book did John Zahm write in 1896?
# Expected answer 53: Evolution and Dogma
#
# Question 54: What professorship did Father Josh Carrier hold at Notre Dame?
# Expected answer 54: Professor of Chemistry and Physics
#
# Question 55: In what year did Albert Zahm begin comparing aeronatical models at Notre Dame?
# Expected answer 55: 1882
#
# Question 56: Which professor sent the first wireless message in the USA?
# Expected answer 56: Professor Jerome Green
#
# Question 57: In what year did Jerome Green send his first wireless message?
# Expected answer 57: Around 1899
#
# Question 58: Which individual worked on projects at Notre Dame that eventually created neoprene?
# Expected answer 58: Father Julius Nieuwland
#
# Question 59: What did the brother of John Zahm construct at Notre Dame?
# Expected answer 59: an early wind tunnel
#
# Question 60: Work on a germ-free-life ended up in the creation of which Notre Dame institute?
# Expected answer 60: The Lobund Institute
#
# Question 61: Around what time did Lobund of Notre Dame become independent?
# Expected answer 61: the 1940s
#
# Question 62: In what year did Lobund at Notre Dame become an Institute?
# Expected answer 62: 1950
#
# Question 63: The Lobund Institute was merged into the Department of Biology at Notre Dame in what year?
# Expected answer 63: 1958
#
# Question 64: When did study of a germ-free-life begin at Notre Dame?
# Expected answer 64: 1928
#
# Question 65: Gurian created what in 1939 at Notre Dame?
# Expected answer 65: The Review of Politics
#
# Question 66: What was the Review of Politics inspired by?
# Expected answer 66: German Catholic journals
#
# Question 67: Over how many years did Gurian edit the Review of Politics at Notre Dame?
# Expected answer 67: 44
#
# Question 68: Thomas Stritch was an editor of which publican from Notre Dame?
# Expected answer 68: Review of Politics
#
# Question 69: Who was the president of Notre Dame in 2012?
# Expected answer 69: John Jenkins
#
# Question 70: The Kellogg Institute for International Studies is part of which university?
# Expected answer 70: Notre Dame
#
# Question 71: What does the Kroc Institute at Notre Dame focus on?
# Expected answer 71: International Peace studies
#
# Question 72: In what year did Notre Dame begin to host the Global Adaptation Index?
# Expected answer 72: 2013
#
# Question 73: What threat does the Global Adaptation Index study?
# Expected answer 73: climate change
#
# Question 74: How many undergrads were attending Notre Dame in 2014?
# Expected answer 74: 8,448
#
# Question 75: What percentage of students at Notre Dame are the children of former Notre Dame students?
# Expected answer 75: 21–24%
#
# Question 76: How many teams participate in the Notre Dame Bookstore Basketball tournament?
# Expected answer 76: over 700
#
# Question 77: For what cause is money raised at the Bengal Bouts tournament at Notre Dame?
# Expected answer 77: the Holy Cross Missions in Bangladesh
#
# Question 78: How many students in total were at Notre Dame in 2014?
# Expected answer 78: 12,179
#
# Question 79: What percentage of undergrads live on the Notre Dame campus?
# Expected answer 79: 80%
#
# Question 80: How many student housing areas are reserved for Notre Dame's graduate students?
# Expected answer 80: four
#
# Question 81: How many dorms for males are on the Notre Dame campus?
# Expected answer 81: 15
#
# Question 82: What amount of the graduate student body at Notre Dame live on the campus?
# Expected answer 82: 20%
#
# Question 83: There are how many dorms for females at Notre Dame?
# Expected answer 83: 14
#
# Question 84: What is Congregation of Holy Cross in Latin?
# Expected answer 84: Congregatio a Sancta Cruce
#
# Question 85: What percentage of Notre Dame students feel they are Christian?
# Expected answer 85: more than 93%
#
# Question 86: How often is Catholic mass held at Notre Dame in a week?
# Expected answer 86: over 100 times
#
# Question 87: How many chapels are on the Notre Dame campus?
# Expected answer 87: Fifty-seven
#
# Question 88: What amount of the student body of Notre Dame identifies as Catholic?
# Expected answer 88: over 80%
#
# Question 89: What was the music hall at Notre Dame called?
# Expected answer 89: Washington Hall
#
# Question 90: In what year was the Main Building at Notre Dame razed in a fire?
# Expected answer 90: 1879
#
# Question 91: Who was the president of Notre Dame in 1879?
# Expected answer 91: Rev. William Corby
#
# Question 92: On what date was the rebuilding of The Main Building begun at Notre Dame after the fire that claimed the previous?
# Expected answer 92: 17th of May
#
# Question 93: What did the Science Hall at Notre Dame come to be known as?
# Expected answer 93: LaFortune Student Center
#
# Question 94: What type of education was pushed at Notre Dame before its embracing of national standards?
# Expected answer 94: scholastic and classical
#
# Question 95: Which college did Notre Dame add in 1921?
# Expected answer 95: College of Commerce
#
# Question 96: In 1919 a new president of Notre Dame was named, who was it?
# Expected answer 96: Father James Burns
#
# Question 97: Over how many years did the change to national standards undertaken at Notre Dame in the early 20th century take place?
# Expected answer 97: three years
#
# Question 98: Those who attended a Jesuit college may have been forbidden from joining which Law School due to the curricula at the Jesuit institution?
# Expected answer 98: Harvard Law School
#
# Question 99: The Notre Dame football team got a new head coach in 1918, who was it?
# Expected answer 99: Knute Rockne
#
# Question 100: What was the amount of wins Knute Rockne attained at Notre Dame while head coach?
# Expected answer 100: 105
#
# Question 101: In what year did the team lead by Knute Rockne win the Rose Bowl?
# Expected answer 101: 1925
#
# Question 102: How many years was Knute Rockne head coach at Notre Dame?
# Expected answer 102: 13
#
# Question 103: How many national titles were won when Knute Rockne coached at Notre Dame?
# Expected answer 103: three
#
# Question 104: Catholic people identified with Notre Dame, what religious group did people feel Yale represented?
# Expected answer 104: the Protestant establishment
#
# Question 105: Notre Dame students had a showdown in 1924 with which anti-catholic group?
# Expected answer 105: the Ku Klux Klan
#
# Question 106: Which college president of Notre Dame is credited with preventing more confrontations between students and the KKK?
# Expected answer 106: Fr. Matthew Walsh
#
# Question 107: What type of event did the Klan intend to have at Notre Dame in March of 1924?
# Expected answer 107: a week-long Klavern
#
# Question 108: Where did Notre Dame students and the KKK have their encounter?
# Expected answer 108: South Bend
#
# Question 109: Which person became vice-president of Notre Dame in 1933?
# Expected answer 109: Father John Francis O'Hara
#
# Question 110: Who was the president of Notre Dame in 1934?
# Expected answer 110: Father John Francis O'Hara
#
# Question 111: Irvin Abell was given what award by Notre Dame?
# Expected answer 111: Laetare Medal
#
# Question 112: Which year was the Laetare Medal first given out at Notre Dame?
# Expected answer 112: 1883
#
# Question 113: For whos glory did Father O'Hara believed that the Notre Dame football team played?
# Expected answer 113: God
#
# Question 114: Around the time that Rev. Cavanaugh became president of Notre Dame by how much did the undergrad student body of Notre Dame increase?
# Expected answer 114: more than half
#
# Question 115: Which institute involving animal life did Cavanaugh create at Notre Dame?
# Expected answer 115: Lobund Institute for Animal Studies
#
# Question 116: What is O'Shaughnessy Hall of Notre Dame formerly known as?
# Expected answer 116: Hall of Liberal Arts
#
# Question 117: Which president did Notre Dame have in 1947?
# Expected answer 117: Rev. John J. Cavanaugh, C.S.C.
#
# Question 118: Outside of an institute studying animals, what other institute did Cavanugh create at Notre Dame?
# Expected answer 118: Medieval Institute
#
# Question 119: What was the lifespan of Theodore Hesburgh?
# Expected answer 119: 1917–2015
#
# Question 120: In the time that Hesburgh was president of Notre Dame by what factor did the operating budget increase?
# Expected answer 120: 18
#
# Question 121: What was the size of the Notre Dame endowment when Theodore Hesburgh became president?
# Expected answer 121: $9 million
#
# Question 122: During what years was Theodor Hesburgh president of Notre Dame?
# Expected answer 122: 1952–87
#
# Question 123: How many faculty members were at Notre Dame when Hesburgh left the role of president?
# Expected answer 123: 950
#
# Question 124: What type of educational institute is Hesburgh given credit for creating at Notre Dame?
# Expected answer 124: coeducational
#
# Question 125: Which role did Charles Sheedy have at Notre Dame?
# Expected answer 125: Dean of Arts and Letters
#
# Question 126: What title did Thomas Blantz have at Notre Dame?
# Expected answer 126: Vice President of Student Affairs
#
# Question 127: In what year did Notre Dame have its earliest undergraduate that was female?
# Expected answer 127: 1971
#
# Question 128: With what institute did Notre Dame agree to an exchange program in the 1960s?
# Expected answer 128: Saint Mary's College
#
# Question 129: During what years was Edward Malloy president of Notre Dame?
# Expected answer 129: 1987–2005
#
# Question 130: What was the SAT score, on average, at Notre Dame when Edward Malloy became president?
# Expected answer 130: 1240
#
# Question 131: When Malloy became president of Notre Dame what was the size of the endowment?
# Expected answer 131: $350 million
#
# Question 132: When Malloy reached the end of his time as president how much annuals funding for research did Notre Dame have?
# Expected answer 132: more than $70 million
#
# Question 133: The amount of professors at Notre Dame increased by what amount under Malloy?
# Expected answer 133: 500
#
# Question 134: When did John Jenkins become the president of Notre Dame?
# Expected answer 134: 2005
#
# Question 135: In terms of the amount of presidents Notre Dame has had, where is John Jenkins on the list?
# Expected answer 135: 17th
#
# Question 136: Who was the Notre Dame president that preceded John Jenkins?
# Expected answer 136: Malloy
#
# Question 137: Which arena was constructed under Jenkins at Notre Dame?
# Expected answer 137: Compton Family Ice Arena
#
# Question 138: How much money was spent on enhancing Notre Dame Stadium under John Jenkins?
# Expected answer 138: $400m
#
# Question 139: Which congregation is in charge of the Old College at Notre Dame?
# Expected answer 139: Congregation of Holy Cross
#
# Question 140: What structure is found on the location of the original church of Father Sorin at Notre Dame?
# Expected answer 140: Basilica of the Sacred Heart
#
# Question 141: In which architectural style is the Basilica of the Sacred Heart at Notre Dame made?
# Expected answer 141: French Revival
#
# Question 142: Which individual painted the inside of the Basilica of the Sacred Heart at Notre Dame?
# Expected answer 142: Luigi Gregori
#
# Question 143: In what year was the Grotto of Our Lady of Lourdes at Notre Dame constructed?
# Expected answer 143: 1896
#
# Question 144: Which person oversaw the creation of a science hall at Notre Dame in 1883?
# Expected answer 144: Fr. Zahm
#
# Question 145: In what year did the student union building at Notre Dame get renamed to LaFortune Center?
# Expected answer 145: 1950
#
# Question 146: After which individual was the LaFortune Center Notre Dame named?
# Expected answer 146: Joseph LaFortune
#
# Question 147: How large in square feet is the LaFortune Center at Notre Dame?
# Expected answer 147: 83,000 square feet
#
# Question 148: What is the annual budget of Notre Dame's LaFortune Center?
# Expected answer 148: $1.2 million
#
# Question 149: How many halls are at Notre Dame that house students?
# Expected answer 149: 29
#
# Question 150: Which library was built at Notre Dame in 1963?
# Expected answer 150: Theodore Hesburgh Library
#
# Question 151: How many books are housed at the Theodore Hesburgh Library?
# Expected answer 151: almost 4 million
#
# Question 152: Construction for which hall started on March 8th 2007 at Notre Dame?
# Expected answer 152: Duncan Hall
#
# Question 153: Which baseball stadium is found at Notre Dame?
# Expected answer 153: Frank Eck Stadium
#
# Question 154: In what year did Notre Dame create the Office of Sustainability?
# Expected answer 154: 2008
#
# Question 155: What percentage of the food served at Notre Dame is locally grown?
# Expected answer 155: 40%
#
# Question 156: Notre Dame got a "B" for its sustainability practices from which entity?
# Expected answer 156: Sustainable Endowments Institute
#
# Question 157: Gustavo Gutierrez is faculty of which institute?
# Expected answer 157: Kroc Institute for International Peace Studies
#
# Question 158: In what year did Notre Dame first have a facility in England?
# Expected answer 158: 1968
#
# Question 159: At which location is the London Center operated by Notre Dame found?
# Expected answer 159: 1 Suffolk Street in Trafalgar Square
#
# Question 160: Notre Dame has a center in Beijing, what is it referred to as?
# Expected answer 160: Global Gateways
#
# Question 161: In what year did the Suffolk Street location start to house a Notre Dame facility?
# Expected answer 161: 1998
#
# Question 162: What was Notre Dame's first college?
# Expected answer 162: The College of Arts and Letters
#
# Question 163: In what year was the The College of Arts and Letters at Notre Dame created?
# Expected answer 163: 1842
#
# Question 164: In what year did the College of Arts and Letters at Notre Dame grant its first degree?
# Expected answer 164: 1849
#
# Question 165: On which university did Notre Dame base its curriculum on?
# Expected answer 165: Saint Louis University
#
# Question 166: How many BA majors does the College of Arts and Letters at Notre Dame offer?
# Expected answer 166: 33
#
# Question 167: Which president at Notre Dame created the College of Science?
# Expected answer 167: Father Patrick Dillon
#
# Question 168: In what year was the Notre Dame College of Science formed?
# Expected answer 168: 1865
#
# Question 169: How many years long was a scientific course under Patrick Dillon at Notre Dame?
# Expected answer 169: six years
#
# Question 170: Which hall at Notre Dame contains the current College of Science?
# Expected answer 170: Jordan Hall of Science
#
# Question 171: How many undergrad students attend the College of Science at Notre Dame today?
# Expected answer 171: over 1,200
#
# Question 172: In 1899 Notre Dame formed which college?
# Expected answer 172: School of Architecture
#
# Question 173: In what building is the current School of Architecture housed at Notre Dame?
# Expected answer 173: Bond Hall
#
# Question 174: What length is the course of study at the Notre Dame School of Architecture?
# Expected answer 174: five-year
#
# Question 175: In which location do students of the School of Architecture of Notre Dame spend their 3rd year?
# Expected answer 175: Rome
#
# Question 176: Which prestigious prize does the School of Architecture at Notre Dame give out?
# Expected answer 176: Driehaus Architecture Prize
#
# Question 177: In what year did the opening of a theology library at Notre Dame occur?
# Expected answer 177: 2015
#
# Question 178: Where is the theology library at Notre Dame?
# Expected answer 178: the first floor of Stanford Hall
#
# Question 179: How many books are held by the Notre Dame libraries?
# Expected answer 179: over three million volumes
#
# Question 180: Currently where does Notre Dame's library rank in the nation?
# Expected answer 180: one of the 100 largest
#
# Question 181: What caused many intellectual Catholics to leave europe in the 1930s?
# Expected answer 181: The rise of Hitler and other dictators
#
# Question 182: From where did Anton-Hermann Chroust come to reach Notre Dame?
# Expected answer 182: Germany
#
# Question 183: What field of study did Anton-Hermann Chroust specialize in?
# Expected answer 183: classics and law
#
# Question 184: Who did Waldemar Gurian receive his tutelage under while seeking his doctorate?
# Expected answer 184: Max Scheler
#
# Question 185: What was Ivan Meštrović known for being?
# Expected answer 185: a renowned sculptor
#
# Question 186: The school known as Notre Dame is known by a more lengthy name, what is it?
# Expected answer 186: University of Notre Dame du
#
# Question 187: What type of institution is the Notre Dame?
# Expected answer 187: Catholic research university
#
# Question 188: The French words Notre Dame du Lac translate to what in English?
# Expected answer 188: Our Lady of the Lake
#
# Question 189: Who is the patron saint of Notre Dame?
# Expected answer 189: the Virgin Mary
#
# Question 190: How large is Notre Dame in acres?
# Expected answer 190: 1,250
#
# Question 191: What caused Notre Dame to become notable in the early 20th century?
# Expected answer 191: its Fighting Irish football team
#
# Question 192: Which 20th century Notre Dame football coach is most notable?
# Expected answer 192: Knute Rockne
#
# Question 193: Which athletic association are the student athletes at Notre Dame a part of?
# Expected answer 193: NCAA Division I
#
# Question 194: How many students at Notre Dame received the Heisman Trophy?
# Expected answer 194: seven
#
# Question 195: There were multiple students from Notre Dame who entered the Pro Football Hall of Fame, how many?
# Expected answer 195: 13
#
# Question 196: Where among US universities does Notre Dame rank?
# Expected answer 196: among the top twenty
#
# Question 197: How many individual colleges are part of Notre Dame?
# Expected answer 197: four
#
# Question 198: Which prize does the Architecture School at Notre Dame give out?
# Expected answer 198: Driehaus Architecture Prize
#
# Question 199: How many doctorate and masters programs are available at Notre Dame?
# Expected answer 199: more than 50
#
# Question 200: Which art museum does Notre Dame administer?
# Expected answer 200: Snite Museum of Art
#
# Question 201: In what year was Father Edward Sorin given two years to create a college?
# Expected answer 201: 1842
#
# Question 202: Which individual offered land to Father Edward Sorin?
# Expected answer 202: Célestine Guynemer de la Hailandière
#
# Question 203: Which church was Father Edward Sorin representing?
# Expected answer 203: the Congregation of the Holy Cross
#
# Question 204: On what date did brothers from Holy Cross arrive at the future location of Notre Dame?
# Expected answer 204: November 26, 1842
#
# Question 205: Which structure was the first used for the purposes of the college?
# Expected answer 205: Father Stephen Badin's old log chapel
#
# Question 206: In what year did the initial degrees get handed out at Notre Dame?
# Expected answer 206: 1849
#
# Question 207: In what year did the original Sorin built Main Building get replaced?
# Expected answer 207: 1865
#
# Question 208: Which individual began a library at Notre Dame?
# Expected answer 208: Father Lemonnier
#
# Question 209: In what year had the library at Notre Dame reach 10,000 books?
# Expected answer 209: 1879
#
# Question 210: In what year was the library at Notre Dame started?
# Expected answer 210: 1873
#
# Question 211: Which television station finds its home at Notre Dame?
# Expected answer 211: NDtv
#
# Question 212: How many programs did NDtv feature in 2002?
# Expected answer 212: one show
#
# Question 213: Which radio station provides radio to the students of Notre Dame at 88.9 FM?
# Expected answer 213: WSND-FM
#
# Question 214: Which internet radio station of Notre Dame is served as an internet stream?
# Expected answer 214: WVFI
#
# Question 215: How much is Eddy Street Commons at Notre Dame expected to cost?
# Expected answer 215: $215 million
#
# Question 216: When was ground broke on the Eddy Street Commons Project of Notre Dame?
# Expected answer 216: June 3, 2008
#
# Question 217: Who is the developer of Eddy Street Commons?
# Expected answer 217: Kite Realty
#
# Question 218: Which entity did Notre Dame hire to build a parking structure outside of Eddy Street Commons?
# Expected answer 218: the City of South Bend
#
# Question 219: There were protested as a part of the construction at Eddy Street Commons, they came due tot he hiring of whom?
# Expected answer 219: non-union workers
#
# Question 220: What does the acronym NCAA stand for?
# Expected answer 220: National Collegiate Athletic Association
#
# Question 221: Which league did Notre Dame Fighting Irish teams participate in in 1982?
# Expected answer 221: Horizon League
#
# Question 222: What when conference do the Notre Dame fencing teams take part in?
# Expected answer 222: Midwest Fencing Conference
#
# Question 223: There is a conference that the male hockey team of Notre Dame competes in, what is it?
# Expected answer 223: Hockey East
#
# Question 224: In what conference did the Fighting Irish take part in in 2012?
# Expected answer 224: Big East Conference
#
# Question 225: To what conference did the Fighting Irish go after the Big East?
# Expected answer 225: the ACC
#
# Question 226: How many teams in each season do the Fighting Irish commit to play against ACC opponents?
# Expected answer 226: five
#
# Question 227: Where did the Fighting Irish hockey team compete prior to a move to Hockey East, in terms of conference?
# Expected answer 227: Central Collegiate Hockey Association
#
# Question 228: What colors are the official ones used by Notre Dame in sport competition?
# Expected answer 228: Navy Blue and Gold Rush
#
# Question 229: What type of mascot do the Notre Dame sport teams have?
# Expected answer 229: Leprechaun
#
# Question 230: Who currently provides uniforms to Notre Dame sport teams?
# Expected answer 230: Under Armour
#
# Question 231: What is the value of the contract between Under Armour and Notre Dame?
# Expected answer 231: almost $100 million
#
# Question 232: When did the Notre Dame marching band form?
# Expected answer 232: 1846
#
# Question 233: What is notable about the Notre Dame marching band?
# Expected answer 233: oldest university band in continuous existence in the United States
#
# Question 234: What is the Notre Dame fight song?
# Expected answer 234: Notre Dame Victory March
#
# Question 235: Which team did Notre Dame's football team find inspiration from?
# Expected answer 235: Michigan Wolverines football team
#
# Question 236: In what year did Notre Dame football begin?
# Expected answer 236: 1887
#
# Question 237: What university is Notre Dame tied with in terms of most Heisman Trophy winners?
# Expected answer 237: Ohio State University
#
# Question 238: Against which team does Notre Dame compete for the Jeweled Shillelagh?
# Expected answer 238: USC
#
# Question 239: In terms of Notre Dame students in the College Football Hall of Fame the amount of students named is what ?
# Expected answer 239: the most
#
# Question 240: What notable football player played at Notre Dame from 1916 to 1920?
# Expected answer 240: George Gipp
#
# Question 241: Against which opponent did Knute Rockne tell his team to "win one for the Gipper?"
# Expected answer 241: the Army team
#
# Question 242: Which person portrayed Knute Rockne in the 1940 movie "Knute Rockne?"
# Expected answer 242: Pat O'Brien
#
# Question 243: Ronald Reagan played the role of whom in 1940's "Knute Rockne?"
# Expected answer 243: Gipp
#
# Question 244: How many seats are in Notre Dame Stadium?
# Expected answer 244: 80,795
#
# Question 245: What is displayed at Zahm House for football home games at Notre Dame?
# Expected answer 245: two-story banner
#
# Question 246: What occurs at midnight preceding a football home game at Notre Dame?
# Expected answer 246: the Drummers' Circle
#
# Question 247: From where does the Band of the Fighting Irish lead a march to the Notre Dame Stadium for football home games?
# Expected answer 247: the steps of Bond Hall
#
# Question 248: What songs does the trumpet section of the Band of the Fighting Irish play preceding home football games?
# Expected answer 248: the Notre Dame Victory March and the Notre Dame Alma Mater
#
# Question 249: On what day do Notre Dame home football games occur?
# Expected answer 249: Saturday
#
# Question 250: How many wins does the Notre Dame men's basketball team have?
# Expected answer 250: over 1,600
#
# Question 251: How many schools have a similar men's basketball record to Notre Dame in terms of wins?
# Expected answer 251: 12
#
# Question 252: How many NCAA tournaments did the Notre Dame men's basketball team take part in?
# Expected answer 252: 28
#
# Question 253: Which Notre Dame men's basketball player has the record for more points in one game?
# Expected answer 253: Austin Carr
#
# Question 254: Who was the Notre Dame men's basketball coach in 2014?
# Expected answer 254: Mike Brey
#
# Question 255: Who wrote the original lyrics to the Notre Dame Victory March?
# Expected answer 255: John F. Shea
#
# Question 256: In what year did Michael J. Shea graduate from Notre Dame?
# Expected answer 256: 1904
#
# Question 257: Who is responsible for writing the music for "Notre Dame Victory March?"
# Expected answer 257: Rev. Michael J. Shea
#
# Question 258: In what year did "Notre Dame Victory March" get copyrighted?
# Expected answer 258: 1928
#
# Question 259: To where are the loyal sons in "Notre Dame Fight Song" marching?
# Expected answer 259: onward to victory
#
# Question 260: Ronald Reagan had a nickname, what was it?
# Expected answer 260: The Gipper
#
# Question 261: In what film did a parody of the "Win one for the Gipper" speech appear?
# Expected answer 261: Airplane!
#
# Question 262: Who starred as Daniel Ruettiger in the film Rudy?
# Expected answer 262: Sean Astin
#
# Question 263: Which person was a former comrade to Ted Striker in the film Airplane!?
# Expected answer 263: George Zipp
#
# Question 264: Pat O'Brien portrayed which person in the film Knute Rockne?
# Expected answer 264: Knute Rockne
#
# Question 265: Which Secretary of State attended Notre Dame?
# Expected answer 265: Condoleezza Rice
#
# Question 266: Which Notre Dame alum from the College of Science won a Nobel Prize?
# Expected answer 266: Eric F. Wieschaus
#
# Question 267: Who is the current president of Notre Dame?
# Expected answer 267: Rev. John Jenkins
#
# Question 268: Mariel Zagunis is notable for winning what?
# Expected answer 268: Olympic gold
#
# Question 269: Which notable astronaut is known to have attended Notre Dame?
# Expected answer 269: Jim Wetherbee
#
# Question 270: When did Beyonce start becoming popular?
# Expected answer 270: in the late 1990s
#
# Question 271: What areas did Beyonce compete in when she was growing up?
# Expected answer 271: singing and dancing
#
# Question 272: When did Beyonce leave Destiny's Child and become a solo singer?
# Expected answer 272: 2003
#
# Question 273: In what city and state did Beyonce  grow up?
# Expected answer 273: Houston, Texas
#
# Question 274: In which decade did Beyonce become famous?
# Expected answer 274: late 1990s
#
# Question 275: In what R&B group was she the lead singer?
# Expected answer 275: Destiny's Child
#
# Question 276: What album made her a worldwide known artist?
# Expected answer 276: Dangerously in Love
#
# Question 277: Who managed the Destiny's Child group?
# Expected answer 277: Mathew Knowles
#
# Question 278: In what city did Beyonce grow up?
# Expected answer 278: Houston
#
# Question 279: What was the name of Beyonce's first solo album?
# Expected answer 279: Dangerously in Love
#
# Question 280: On what date was Beyonce born?
# Expected answer 280: September 4, 1981
#
# Question 281: What is Beyonce's full name?
# Expected answer 281: Beyoncé Giselle Knowles-Carter
#
# Question 282: When did Beyoncé rise to fame?
# Expected answer 282: late 1990s
#
# Question 283: What role did Beyoncé have in Destiny's Child?
# Expected answer 283: lead singer
#
# Question 284: What was the first album Beyoncé released as a solo artist?
# Expected answer 284: Dangerously in Love
#
# Question 285: When did Beyoncé release Dangerously in Love?
# Expected answer 285: 2003
#
# Question 286: How many Grammy awards did Beyoncé win for her first solo album?
# Expected answer 286: five
#
# Question 287: What was Beyoncé's role in Destiny's Child?
# Expected answer 287: lead singer
#
# Question 288: What was the name of Beyoncé's first solo album?
# Expected answer 288: Dangerously in Love
#
# Question 289: When did Beyoncé release her first solo album?
# Expected answer 289: 2003
#
# Question 290: After her second solo album, what other entertainment venture did Beyonce explore?
# Expected answer 290: acting
#
# Question 291: Which artist did Beyonce marry?
# Expected answer 291: Jay Z
#
# Question 292: To set the record for Grammys, how many did Beyonce win?
# Expected answer 292: six
#
# Question 293: For what movie did Beyonce receive  her first Golden Globe nomination?
# Expected answer 293: Dreamgirls
#
# Question 294: When did Beyonce take a hiatus in her career and take control of her management?
# Expected answer 294: 2010
#
# Question 295: Which album was darker in tone from her previous work?
# Expected answer 295: Beyoncé
#
# Question 296: After what movie portraying Etta James, did Beyonce create Sasha Fierce?
# Expected answer 296: Cadillac Records
#
# Question 297: When did Destiny's Child end their group act?
# Expected answer 297: June 2005
#
# Question 298: What was the name of Beyoncé's second solo album?
# Expected answer 298: B'Day
#
# Question 299: What was Beyoncé's first acting job, in 2006?
# Expected answer 299: Dreamgirls
#
# Question 300: Who is Beyoncé married to?
# Expected answer 300: Jay Z
#
# Question 301: What is the name of Beyoncé's alter-ego?
# Expected answer 301: Sasha Fierce
#
# Question 302: In her music, what are some recurring elements in them?
# Expected answer 302: love, relationships, and monogamy
#
# Question 303: Time magazine named her one of the most 100 what people of the century?
# Expected answer 303: influential
#
# Question 304: Which magazine declared her the most dominant woman musician?
# Expected answer 304: Forbes
#
# Question 305: In which decade did the Recording Industry Association of America recognize Beyonce as the The Top Certified Artist?
# Expected answer 305: 2000s
#
# Question 306: What magazine rated Beyonce as the most powerful female musician in 2015?
# Expected answer 306: Forbes
#
# Question 307: How did Beyonce describe herself as a feminist?
# Expected answer 307: modern-day feminist
#
# Question 308: In which years did Time rate Beyonce in the 100 most influential people in the world?
# Expected answer 308: 2013 and 2014
#
# Question 309: How many records has Beyonce sold in her 19 year career?
# Expected answer 309: 118 million
#
# Question 310: How many records did Beyoncé sell as part of Destiny's Child?
# Expected answer 310: 60 million
#
# Question 311: After leaving Destiny's Child, how many records did Beyoncé release under her own name?
# Expected answer 311: 118 million
#
# Question 312: How many Grammy awards has Beyoncé won?
# Expected answer 312: 20
#
# Question 313: What magazine named Beyoncé as the most powerful female musician for 2015?
# Expected answer 313: Forbes
#
# Question 314: Beyonce's younger sibling also sang with her in what band?
# Expected answer 314: Destiny's Child
#
# Question 315: Where did Beyonce get her name from?
# Expected answer 315: her mother's maiden name
#
# Question 316: What race was Beyonce's father?
# Expected answer 316: African-American
#
# Question 317: Beyonce's childhood home believed in what religion?
# Expected answer 317: Methodist
#
# Question 318: Beyonce's father worked as a sales manager for what company?
# Expected answer 318: Xerox
#
# Question 319: Beyonce's mother worked in what industry?
# Expected answer 319: hairdresser and salon owner
#
# Question 320: What younger sister of Beyonce also appeared in Destiny's Child?
# Expected answer 320: Solange
#
# Question 321: Beyonce is a descendent of what Arcadian leader?
# Expected answer 321: Joseph Broussard
#
# Question 322: What company did Beyoncé's father work for when she was a child?
# Expected answer 322: Xerox
#
# Question 323: What did Beyoncé's mother own when Beyoncé was a child?
# Expected answer 323: salon
#
# Question 324: What is the name of Beyoncé's younger sister?
# Expected answer 324: Solange
#
# Question 325: Beyoncé is a descendant of which Acadian leader?
# Expected answer 325: Joseph Broussard.
#
# Question 326: Beyoncé was raised in what religion?
# Expected answer 326: Methodist
#
# Question 327: What town did Beyonce go to school in?
# Expected answer 327: Fredericksburg
#
# Question 328: Who was the first person to notice Beyonce's singing ability?
# Expected answer 328: Darlette Johnson
#
# Question 329: Beyonce moved to which town after she left her first elementary school?
# Expected answer 329: Houston
#
# Question 330: Which of her teachers discovered Beyonce's musical talent?
# Expected answer 330: dance instructor Darlette Johnson
#
# Question 331: I which church was Beyonce  a member and soloist  in the choir?
# Expected answer 331: St. John's United Methodist Church
#
# Question 332: What type of school was Parker Elementary School?
# Expected answer 332: music magnet school
#
# Question 333: Which song did Beyonce sing to win a competition at age 7?
# Expected answer 333: Imagine
#
# Question 334: What city was Beyoncé's elementary school located in?
# Expected answer 334: Fredericksburg
#
# Question 335: What was the name of Beyoncé's first dance instructor?
# Expected answer 335: Darlette Johnson
#
# Question 336: How old was Beyoncé when she won a school talent show?
# Expected answer 336: seven
#
# Question 337: What choir did Beyoncé sing in for two years?
# Expected answer 337: St. John's United Methodist Church
#
# Question 338: Who decided to place Beyonce's group in Star Search the talent show?
# Expected answer 338: Arne Frager
#
# Question 339: In 1995, who decided to manage the girls singing group?
# Expected answer 339: Beyoncé's father
#
# Question 340: Who was the first record label to give the girls a record deal?
# Expected answer 340: Elektra Records
#
# Question 341: Who brought Beyonce to California and enter her group in Star Search?
# Expected answer 341: Arne Frager
#
# Question 342: In what year did Beyonce's father quit his job to manage her group?
# Expected answer 342: 1995
#
# Question 343: What large record company recorded Beyonce's group's first album?
# Expected answer 343: Sony Music
#
# Question 344: What record company first signed Beyonce's group and later cut them?
# Expected answer 344: Elektra Records
#
# Question 345: At what age did Beyonce meet LaTavia Robertson?
# Expected answer 345: age eight
#
# Question 346: How old was Beyoncé when she met LaTavia Roberson?
# Expected answer 346: eight
#
# Question 347: What was the name of the first group Beyoncé was a part of?
# Expected answer 347: Girl's Tyme
#
# Question 348: Who placed Girl's Tyme in Star Search?
# Expected answer 348: Arne Frager
#
# Question 349: When did Beyoncé begin to manage the girl group?
# Expected answer 349: 1995
#
# Question 350: Who signed the girl group on October 5, 1995?
# Expected answer 350: Dwayne Wiggins's Grass Roots Entertainment
#
# Question 351: Which film featured Destiny's Child's first major single?
# Expected answer 351: Men in Black
#
# Question 352: For which song, did Destiny's Child take home the grammy award for best R&B performance?
# Expected answer 352: "Say My Name"
#
# Question 353: Who did Beyonce record with for the movie "The Best Man?"
# Expected answer 353: Marc Nelson
#
# Question 354: Beyonce's group changed their name to Destiny's Child in what year?
# Expected answer 354: 1996
#
# Question 355: The name Destiny's Child was based on a quote in which book of the Bible?
# Expected answer 355: Book of Isaiah
#
# Question 356: Debut song, "Killing Time" was featured on what movie's sound track?
# Expected answer 356: Men in Black
#
# Question 357: What song won Best R&B Performance in the 43 Annual Grammy Awards?
# Expected answer 357: Say My Name
#
# Question 358: What singer did Beyonce record a song with for the movie, ''The Best Man"?
# Expected answer 358: Marc Nelson
#
# Question 359: Where did Destiny's Child get their name from?
# Expected answer 359: Book of Isaiah.
#
# Question 360: Destiny's Child song, Killing Time, was included in which film's soundtrack?
# Expected answer 360: Men in Black.
#
# Question 361: What was Destiny's Child's first major song hit?
# Expected answer 361: No, No, No
#
# Question 362: When did Destiny's Child release their second album?
# Expected answer 362: 1999
#
# Question 363: Who did Beyoncé sing a duet with for "The Best Man" film?
# Expected answer 363: Marc Nelson
#
# Question 364: What mental health issue did Beyonce go through?
# Expected answer 364: depression
#
# Question 365: What event occured after she was publicly criticized?
# Expected answer 365: boyfriend left her
#
# Question 366: Who supported Beyonce through her depression?
# Expected answer 366: her mother
#
# Question 367: What event caused Beyonce's depression?
# Expected answer 367: split with Luckett and Rober
#
# Question 368: How long was Beyonce depressed?
# Expected answer 368: a couple of years
#
# Question 369: Who helped Beyonce fight her depression the most?
# Expected answer 369: her mother
#
# Question 370: Who replaced Luckett and Roberson in Destiny's Child?
# Expected answer 370: Farrah Franklin and Michelle Williams.
#
# Question 371: Who was blamed for Luckett and Roberson leaving Destiny's Child?
# Expected answer 371: Beyoncé
#
# Question 372: Who helped Beyoncé overcome her depression during the years following the Destiny's Child split?
# Expected answer 372: her mother
#
# Question 373: Which newest member was removed from Destiny's Child?
# Expected answer 373: Farrah Franklin
#
# Question 374: "Charlie's Angels" featured which single from the band members?
# Expected answer 374: Independent Women Part I
#
# Question 375: How many weeks did their single "Independent Women Part I" stay on top?
# Expected answer 375: eleven
#
# Question 376: For what network, did Beyonce land a major movie role in?
# Expected answer 376: MTV
#
# Question 377: Their third album, Survivor, sold how many during its first week?
# Expected answer 377: 663,000 copies
#
# Question 378: What French composer wrote the original opera ''Carmen'' in the 19th century?
# Expected answer 378: Georges Bizet
#
# Question 379: What album caused a lawsuit to be filed in 2001?
# Expected answer 379: Survivor
#
# Question 380: Independent Women Part I was on which 2000 film's soundtrack?
# Expected answer 380: Charlie's Angels.
#
# Question 381: Which film did Beyoncé star in 2001 with Mekhi Phifer?
# Expected answer 381: Carmen: A Hip Hopera
#
# Question 382: What was the name of Destiny Child's third album?
# Expected answer 382: Survivor
#
# Question 383: Who filed a lawsuit over Survivor?
# Expected answer 383: Luckett and Roberson
#
# Question 384: When did Destiny's Child announce their hiatus?
# Expected answer 384: October 2001
#
# Question 385: Who did Beyonce star with in the movie, "Austin Powers in Goldmember"?
# Expected answer 385: Mike Myers
#
# Question 386: Which three countries did Beyonce's song "Work It Out" achieve top ten status?
# Expected answer 386: UK, Norway, and Belgium
#
# Question 387: Beyonce starred with Cuba Gooding Jr. in which film?
# Expected answer 387: The Fighting Temptations
#
# Question 388: Who did Beyonce record the lead single with in the movie "The Fighting Temptations"?
# Expected answer 388: Missy Elliott
#
# Question 389: Which other song from the soundtrack did better in the charts?
# Expected answer 389: Summertime
#
# Question 390: What film did Beyonce appear in with Mike Myers?
# Expected answer 390: Austin Powers in Goldmember
#
# Question 391: What large amount did the movie "Goldmember" gross?
# Expected answer 391: 73 million
#
# Question 392: What genre of movie did Beyonce star in with Cuba Gooding, Jr?
# Expected answer 392: musical comedy
#
# Question 393: What song was the lead single from the film's sound track?
# Expected answer 393: Fighting Temptations
#
# Question 394: How did the critics view the movie, ''The Fighting Temptations''?
# Expected answer 394: mixed reviews
#
# Question 395: What film did Beyoncé star in with Mike Myers in 2002?
# Expected answer 395: Austin Powers in Goldmember
#
# Question 396: What was Beyoncé's character called in Austin Powers in Goldmember?
# Expected answer 396: Foxxy Cleopatra
#
# Question 397: Which song did Beyoncé release as the lead single for Austin Powers in Goldmember's soundtrack?
# Expected answer 397: Work It Out
#
# Question 398: What musical comedy did Beyoncé star in along with Cuba Gooding, Jr. in 2003?
# Expected answer 398: The Fighting Temptations
#
# Question 399: What song did Beyoncé release as the lead single from The Fighting Tempations?
# Expected answer 399: Fighting Temptations
#
# Question 400: What was the highest Beyonce's first solo recording achieved in the Billboard Hot 100?
# Expected answer 400: number four
#
# Question 401: Beyonce's first album by herself was called what?
# Expected answer 401: Dangerously in Love
#
# Question 402: How many has "Dangerously in Love" sould worldwide since its debut?
# Expected answer 402: 11 million
#
# Question 403: Beyonce's first number one song was which song?
# Expected answer 403: Crazy in Love
#
# Question 404: How many top five singles came from her first album?
# Expected answer 404: four
#
# Question 405: Beyonce's first solo album in the U.S. with what artist in the lead single?
# Expected answer 405: Jay Z
#
# Question 406: What solo album did Beyonce release in 2003?
# Expected answer 406: Dangerously in Love
#
# Question 407:  The album, Dangerously in Love  achieved what spot on the Billboard Top 100 chart?
# Expected answer 407: number four
#
# Question 408: "The Closer I get to You" was recorded with which artist?
# Expected answer 408: Luther Vandross
#
# Question 409: Which artist was associated with Beyoncé's premiere solo recording?
# Expected answer 409: Jay Z
#
# Question 410: When did Beyoncé release her first solo album?
# Expected answer 410: June 24, 2003
#
# Question 411: What is the lead single on Beyoncé's first album?
# Expected answer 411: Crazy in Love
#
# Question 412: Who helped Beyoncé earn a Grammy award for Best R&B Performance by a Duo or Group at the 46th annual Grammy Awards?
# Expected answer 412: Luther Vandross.
#
# Question 413: How many awards did Beyoncé win at the 46th Grammy's Awards?
# Expected answer 413: five.
#
# Question 414: Destiny's Child's final album was named what?
# Expected answer 414: Destiny Fulfilled
#
# Question 415: Destiny's Child got a star on the Hollywood Walk of Fame in what year?
# Expected answer 415: 2006
#
# Question 416: In what year did Beyonce embark on her Dangerously in Love tour of Europe?
# Expected answer 416: November 2003
#
# Question 417: What was the name of the final album of Destiny's Child?
# Expected answer 417: Destiny Fulfilled
#
# Question 418: It was announced that Destiny's Child would  disban in what European city?
# Expected answer 418: Barcelona
#
# Question 419: When did Destiny's Child get their star on the Hollywood Walk of Fame?
# Expected answer 419: March 2006
#
# Question 420: What was the name of Beyoncé's European start that started in November 2003?
# Expected answer 420: Dangerously in Love Tour
#
# Question 421: Who did Beyoncé tour with for the Verizon Lades First Tour?
# Expected answer 421: Missy Elliott and Alicia Keys
#
# Question 422: What major event did Beyoncé perform at on February 1, 2004?
# Expected answer 422: Super Bowl XXXVIII
#
# Question 423: What is the name of the final studio album from Destiny's Child?
# Expected answer 423: Destiny Fulfilled.
#
# Question 424: How many albums did Beyonce sell in the first week when she released her second album?
# Expected answer 424: 541,000
#
# Question 425: The lead single from the album was which song?
# Expected answer 425: Déjà Vu
#
# Question 426: How many countries did her song "Irreplaceable" get number one status in?
# Expected answer 426: five
#
# Question 427: How many singles did her second album produce?
# Expected answer 427: five
#
# Question 428: What birthday did Beyonce's album B'Day celebrate?
# Expected answer 428: twenty-fifth birthday
#
# Question 429: What artist did Beyonce duet with in the single, "Deja Vu''?
# Expected answer 429: Jay Z
#
# Question 430: How high did ''Deja Vu'' climb on the Billboard chart?
# Expected answer 430: top five
#
# Question 431: What is the name of Beyoncé's second album?
# Expected answer 431: B'Day
#
# Question 432: How many copies did B'Day sell during the first week of its release?
# Expected answer 432: 541,000
#
# Question 433: Who collaborated with Beyoncé on the single, Deja Vu?
# Expected answer 433: Jay Z
#
# Question 434: Which single from B'Day was only released in the U.K.?
# Expected answer 434: Green Light
#
# Question 435: What movie did Beyonce act in 2006?
# Expected answer 435: The Pink Panther
#
# Question 436: Her second movie Beyonce did was what film?
# Expected answer 436: Dreamgirls
#
# Question 437: The single, "Listen" was featured in which movie?
# Expected answer 437: Dreamgirls
#
# Question 438: Beyonce's first world tour was when?
# Expected answer 438: 2007
#
# Question 439: How much money did Beyonce's tour make in 2007?
# Expected answer 439: 24 million
#
# Question 440: How many millions of dollars did ''The Pink Panther'' gross world-wide?
# Expected answer 440: 158.8 million
#
# Question 441: What did Beyonce call her first concert tour?
# Expected answer 441: The Beyoncé Experience
#
# Question 442: Who was Beyonce's duet with in ''Beautiful Liar''?
# Expected answer 442: Shakira
#
# Question 443: Which film did Beyoncé star with Steve Martin in?
# Expected answer 443: The Pink Panther
#
# Question 444: Beyoncé's role in Dreamgirls was based on what pop singer?
# Expected answer 444: Diana Ross.
#
# Question 445: What was the lead single for the Dreamgirls soundtrack?
# Expected answer 445: Listen
#
# Question 446: What was the name of Beyoncé's first international tour?
# Expected answer 446: The Beyoncé Experience
#
# Question 447: What pop singer did a duet with Beyoncé on Beautiful Liar?
# Expected answer 447: Shakira
#
# Question 448: Beyonce got married in 2008 to whom?
# Expected answer 448: Jay Z
#
# Question 449: Her third album, "I am...Sasha Fierce" was released when?
# Expected answer 449: November 18, 2008
#
# Question 450: For which decade, did Beyonce have more top ten songs than any other woman?
# Expected answer 450: 2000s
#
# Question 451: Which singer beat out Beyonce for best video performance?
# Expected answer 451: Taylor Swift
#
# Question 452: In 2009, Beyonce started her second world tour and grossed how much money?
# Expected answer 452: 119.5 million
#
# Question 453: How did she reveal the marriage?
# Expected answer 453: in a video montage
#
# Question 454: When did Beyonce begin her second world tour?
# Expected answer 454: March 2009
#
# Question 455: Who beat out Beyonce for Best Female Video ?
# Expected answer 455: Taylor Swift
#
# Question 456: How much did the second world tour make in dollars?
# Expected answer 456: 119.5 million
#
# Question 457: When did Beyoncé get married?
# Expected answer 457: April 4, 2008
#
# Question 458: Who did Beyoncé marry?
# Expected answer 458: Jay Z.
#
# Question 459: Who is Beyoncé's alter ego?
# Expected answer 459: Sasha Fierce
#
# Question 460: The video for what song won Beyoncé the 2009 MTV Video of the Year award?
# Expected answer 460: Single Ladies
#
# Question 461: Which prominent star felt the 2009 Female Video of the Year award should have went to Beyoncé instead of Taylor Swift?
# Expected answer 461: Kanye West
#
# Question 462: Beyonce portrayed which character in the film, Cadillac Records?
# Expected answer 462: Etta James
#
# Question 463: Beyonce gave her entire salary from Cadillac Records to which organization?
# Expected answer 463: Phoenix House
#
# Question 464: Which song did Beyonce sing at the first couple's inaugural ball?
# Expected answer 464: At Last
#
# Question 465: What genre of film was the movie, Obsessed, in which Beyonce starred in?
# Expected answer 465: thriller
#
# Question 466: A fight scene from the movie, Obsessed, won which award for Beyonce?
# Expected answer 466: MTV Movie Award for Best Fight
#
# Question 467: Where did Beyonce donate her salary from the movie Cadillac Records?
# Expected answer 467: Phoenix House
#
# Question 468: What thriller film did Beyonce star in?
# Expected answer 468: Obsessed
#
# Question 469: What was the name of the woman she played in Obsessed?
# Expected answer 469: Sharon Charles
#
# Question 470: How much more that the buget did the film gross?
# Expected answer 470: 60 million
#
# Question 471: Which singer did Beyoncé portray in Cadillac Records?
# Expected answer 471: Etta James
#
# Question 472: Which organization received Beyoncé's entire Cadillac Records salary?
# Expected answer 472: Phoenix House
#
# Question 473: Where did Beyoncé perform on January 20, 2009?
# Expected answer 473: the First Couple's first inaugural ball.
#
# Question 474: Which thriller film did Beyoncé star in with Ali Larter?
# Expected answer 474: Obsessed.
#
# Question 475: How many awards was Beyonce nominated for at the 52nd Grammy Awards?
# Expected answer 475: ten
#
# Question 476: Beyonce tied with which artist for most nominations by a female artist?
# Expected answer 476: Lauryn Hill
#
# Question 477: In 2010, Beyonce worked with which other famous singer?
# Expected answer 477: Lady Gaga
#
# Question 478: How many number one singles did Beyonce now have after the song "Telephone"?
# Expected answer 478: six
#
# Question 479: Beyonce tied who for most number one singles by a female?
# Expected answer 479: Mariah Carey
#
# Question 480: Beyonce received how many nominations at the 52nd Annual Grammy Awards?
# Expected answer 480: ten nominations
#
# Question 481: What song was the sixth first place song for Beyonce?
# Expected answer 481: Telephone
#
# Question 482: Who else appeared with Beyonce in Telephone?
# Expected answer 482: Lady Gaga
#
# Question 483: Who did they tie with for six top songs?
# Expected answer 483: Mariah Carey
#
# Question 484: Who did Beyonce tie with for the most nominations in a year?
# Expected answer 484: Lauryn Hill
#
# Question 485: How many nominations did Beyoncé receive at the 52nd Grammy Awards ceremony?
# Expected answer 485: ten
#
# Question 486: Who did Beyoncé tie with for the most Grammy nominations for female artists?
# Expected answer 486: Lauryn Hill
#
# Question 487: Beyoncé was a featured artist on which singer's hit, Telephone?
# Expected answer 487: Lady Gaga
#
# Question 488: Who did Beyoncé and Lady Gaga tie with for the most number one hits since 1992?
# Expected answer 488: Mariah Carey
#
# Question 489: Beyonce would take a break from music in which year?
# Expected answer 489: 2010
#
# Question 490: Which year did Beyonce and her father part business ways?
# Expected answer 490: 2010
#
# Question 491: Which famous landmark did Beyonce see in China?
# Expected answer 491: the Great Wall of China
#
# Question 492: In what year did Beyonce have her hiatus?
# Expected answer 492: 2010
#
# Question 493: Who inspired this hiatus?
# Expected answer 493: her mother
#
# Question 494: When did she stop using her father as a manager?
# Expected answer 494: During the break
#
# Question 495: How long did the hiatus last?
# Expected answer 495: nine months
#
# Question 496: What did Beyoncé announce in January 2010?
# Expected answer 496: a hiatus
#
# Question 497: Who suggested the hiatus for Beyoncé?
# Expected answer 497: her mother
#
# Question 498: Who did Beyoncé part ways with during her hiatus?
# Expected answer 498: her father
#
# Question 499: How long did her hiatus last?
# Expected answer 499: nine months
#
# Question 500: In which year was reports about Beyonce performing for Muammar Gaddafi surface?
# Expected answer 500: 2011

# %%
# Google Cloud Vertex AI access configuration
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "gcp-key.json"

# Initialization of the native Google client (identical to the server)
google_client = genai.Client(
    vertexai=True,
    project="info-h512-project-rag-project",
    location="europe-west1"
)

# Definition of the local FastAPI server URL
API_URL = "http://localhost:8000/api/ask"

# Global Evaluation Function
def evaluate_method(method_id: int):
    # Read the custom SQuAD CSV file
    eval_pairs_df = pd.read_csv("squad_eval_pairs.csv")
    results = []
    
    print(f"Collecting API responses for method {method_id}...")
    for _, sample in eval_pairs_df.iterrows():
        try:
            response = requests.post(
                API_URL,
                json={"question": sample['question'], "method": method_id},
                timeout=60
            )
            response.raise_for_status()
            res_json = response.json()
            
            # Extraction from CSV header 'expected_answer' and 'context' 
            ground_truth_text = str(sample['expected_answer'])
            gold_context = sample['context']
            results.append((res_json, ground_truth_text, gold_context))
            
        except Exception as e:
            print(f"Error with question: {sample['question']} | {e}")
            
    if not results:
        print("No data could be collected from the API. Evaluation aborted.")
        return None

    # Structure the final dataset in the strict format required by Ragas
    ragas_dataset = Dataset.from_dict({
        "question":          [r["question"]          for r, _ , _ in results],
        "answer":            [r["answer"]            for r, _ , _ in results],
        "contexts":          [r["retrieved_context"] for r, _ , _ in results], 
        "ground_truth":      [gt                     for _, _, gt in results], 
        "gold_context":      [gc                     for _, _, gc in results]
    })
    
    return ragas_dataset

# %%
# Store results for each method 
evaluation_result = {}

for method_id in range(1, 4):
    ragas_dataset = evaluate_method(method_id)
    df_temp = ragas_dataset.to_pandas()
    df_temp.to_csv(f"scores_ragas_methode_{method_id}.csv", index=False)
# Out:
# Collecting API responses for method 1...
# Collecting API responses for method 2...
# Collecting API responses for method 3...
